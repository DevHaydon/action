# %% [markdown]
# ## Lab 3
#
# ## Let's try out 3 MCP Servers
#
# We will add new powers to our agents:
# 1. Memory
# 2. Internet search
# 3. Live market data
#
# This is where you can really appreciate the benefits of MCP: it makes it so easy to equip our agents with tools that others have developed.

# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace
from agents.mcp import MCPServerStdio
import os
from IPython.display import Markdown, display
from datetime import datetime
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ## First new MCP Server: a persistent knowledge-graph based memory
#
# Here's a really interesting one: a knowledge-graph based memory.
#
# It's a persistent memory store of entities, observations about them, and relationships between them.

# %%
params = {
  "command": "npx",
  "args": ["-y", "mcp-memory-libsql"],
  "env": {
				"LIBSQL_URL": "file:./memory/ed.db"
			}
}


async with MCPServerStdio(params=params, client_session_timeout_seconds=60) as server:
    mcp_tools = await server.list_tools()

mcp_tools
# Out:
# Error initializing MCP server: Timed out while waiting for response to ClientRequest. Waited 60.0 seconds.
# Error cleaning up server: unhandled errors in a TaskGroup (1 sub-exception)
# ---------------------------------------------------------------------------
# WouldBlock                                Traceback (most recent call last)
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/streams/memory.py:111, in MemoryObjectReceiveStream.receive(self)
#     110 try:
# --> 111     return self.receive_nowait()
#     112 except WouldBlock:
#     113     # Add ourselves in the queue
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/streams/memory.py:106, in MemoryObjectReceiveStream.receive_nowait(self)
#     104     raise EndOfStream
# --> 106 raise WouldBlock
#
# WouldBlock:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/_core/_tasks.py:115, in fail_after(delay, shield)
#     112 with get_async_backend().create_cancel_scope(
#     113     deadline=deadline, shield=shield
#     114 ) as cancel_scope:
# --> 115     yield cancel_scope
#     117 if cancel_scope.cancelled_caught and current_time() >= cancel_scope.deadline:
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/mcp/shared/session.py:254, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds)
#     253     with anyio.fail_after(timeout):
# --> 254         response_or_error = await response_stream_reader.receive()
#     255 except TimeoutError:
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/streams/memory.py:119, in MemoryObjectReceiveStream.receive(self)
#     118 try:
# --> 119     await receive_event.wait()
#     120 finally:
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:1774, in Event.wait(self)
#    1773 else:
# -> 1774     await self._event.wait()
#
# File ~/.python/current/lib/python3.12/asyncio/locks.py:212, in Event.wait(self)
#     211 try:
# --> 212     await fut
#     213     return True
#
# CancelledError: Cancelled by cancel scope 72e210030bc0
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File /workspaces/action/.venv/lib/python3.12/site-packages/mcp/shared/session.py:253, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds)
#     252 try:
# --> 253     with anyio.fail_after(timeout):
#     254         response_or_error = await response_stream_reader.receive()
#
# File ~/.python/current/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/_core/_tasks.py:118, in fail_after(delay, shield)
#     117 if cancel_scope.cancelled_caught and current_time() >= cancel_scope.deadline:
# --> 118     raise TimeoutError
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# McpError                                  Traceback (most recent call last)
# Cell In[11], line 10
#       1 params = {
#       2   "command": "npx",
#       3   "args": ["-y", "mcp-memory-libsql"],
#    (...)      6 			}
#       7 }
# ---> 10 async with MCPServerStdio(params=params, client_session_timeout_seconds=60) as server:
#      11     mcp_tools = await server.list_tools()
#      13 mcp_tools
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/agents/mcp/server.py:94, in _MCPServerWithClientSession.__aenter__(self)
#      93 async def __aenter__(self):
# ---> 94     await self.connect()
#      95     return self
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/agents/mcp/server.py:118, in _MCPServerWithClientSession.connect(self)
#     108     read, write = transport
#     109     session = await self.exit_stack.enter_async_context(
#     110         ClientSession(
#     111             read,
#    (...)    116         )
#     117     )
# --> 118     await session.initialize()
#     119     self.session = session
#     120 except Exception as e:
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/mcp/client/session.py:126, in ClientSession.initialize(self)
#     118 sampling = types.SamplingCapability()
#     119 roots = types.RootsCapability(
#     120     # TODO: Should this be based on whether we
#     121     # _will_ send notifications, or only whether
#     122     # they're supported?
#     123     listChanged=True,
#     124 )
# --> 126 result = await self.send_request(
#     127     types.ClientRequest(
#     128         types.InitializeRequest(
#     129             method="initialize",
#     130             params=types.InitializeRequestParams(
#     131                 protocolVersion=types.LATEST_PROTOCOL_VERSION,
#     132                 capabilities=types.ClientCapabilities(
#     133                     sampling=sampling,
#     134                     experimental=None,
#     135                     roots=roots,
#     136                 ),
#     137                 clientInfo=self._client_info,
#     138             ),
#     139         )
#     140     ),
#     141     types.InitializeResult,
#     142 )
#     144 if result.protocolVersion not in SUPPORTED_PROTOCOL_VERSIONS:
#     145     raise RuntimeError(
#     146         "Unsupported protocol version from the server: "
#     147         f"{result.protocolVersion}"
#     148     )
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/mcp/shared/session.py:256, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds)
#     254         response_or_error = await response_stream_reader.receive()
#     255 except TimeoutError:
# --> 256     raise McpError(
#     257         ErrorData(
#     258             code=httpx.codes.REQUEST_TIMEOUT,
#     259             message=(
#     260                 f"Timed out while waiting for response to "
#     261                 f"{request.__class__.__name__}. Waited "
#     262                 f"{timeout} seconds."
#     263             ),
#     264         )
#     265     )
#     267 if isinstance(response_or_error, JSONRPCError):
#     268     raise McpError(response_or_error.error)
#
# McpError: Timed out while waiting for response to ClientRequest. Waited 60.0 seconds.

# %%
instructions = "You use your entity tools as a persistent memory to store and recall information about your conversations."
request = "My name's Ed. I'm running a workshop live about AI Agents right now, \
and I'm co-presenting with the legendary presenter, Jon, from the SuperDataScience podcast."
model = "gpt-4o-mini"

# %%
async with MCPServerStdio(params=params, client_session_timeout_seconds=60) as mcp_server:
    agent = Agent(name="agent", instructions=instructions, model=model, mcp_servers=[mcp_server])
    with trace("conversation"):
        result = await Runner.run(agent, request)
    display(Markdown(result.final_output))
# Out:
# Error initializing MCP server: Timed out while waiting for response to ClientRequest. Waited 60.0 seconds.
# Error cleaning up server: unhandled errors in a TaskGroup (1 sub-exception)
# ---------------------------------------------------------------------------
# WouldBlock                                Traceback (most recent call last)
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/streams/memory.py:111, in MemoryObjectReceiveStream.receive(self)
#     110 try:
# --> 111     return self.receive_nowait()
#     112 except WouldBlock:
#     113     # Add ourselves in the queue
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/streams/memory.py:106, in MemoryObjectReceiveStream.receive_nowait(self)
#     104     raise EndOfStream
# --> 106 raise WouldBlock
#
# WouldBlock:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/_core/_tasks.py:115, in fail_after(delay, shield)
#     112 with get_async_backend().create_cancel_scope(
#     113     deadline=deadline, shield=shield
#     114 ) as cancel_scope:
# --> 115     yield cancel_scope
#     117 if cancel_scope.cancelled_caught and current_time() >= cancel_scope.deadline:
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/mcp/shared/session.py:254, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds)
#     253     with anyio.fail_after(timeout):
# --> 254         response_or_error = await response_stream_reader.receive()
#     255 except TimeoutError:
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/streams/memory.py:119, in MemoryObjectReceiveStream.receive(self)
#     118 try:
# --> 119     await receive_event.wait()
#     120 finally:
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:1774, in Event.wait(self)
#    1773 else:
# -> 1774     await self._event.wait()
#
# File ~/.python/current/lib/python3.12/asyncio/locks.py:212, in Event.wait(self)
#     211 try:
# --> 212     await fut
#     213     return True
#
# CancelledError: Cancelled by cancel scope 75c3d1f79280
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File /workspaces/action/.venv/lib/python3.12/site-packages/mcp/shared/session.py:253, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds)
#     252 try:
# --> 253     with anyio.fail_after(timeout):
#     254         response_or_error = await response_stream_reader.receive()
#
# File ~/.python/current/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/_core/_tasks.py:118, in fail_after(delay, shield)
#     117 if cancel_scope.cancelled_caught and current_time() >= cancel_scope.deadline:
# --> 118     raise TimeoutError
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# McpError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 async with MCPServerStdio(params=params, client_session_timeout_seconds=60) as mcp_server:
#       2     agent = Agent(name="agent", instructions=instructions, model=model, mcp_servers=[mcp_server])
#       3     with trace("conversation"):
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/agents/mcp/server.py:94, in _MCPServerWithClientSession.__aenter__(self)
#      93 async def __aenter__(self):
# ---> 94     await self.connect()
#      95     return self
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/agents/mcp/server.py:118, in _MCPServerWithClientSession.connect(self)
#     108     read, write = transport
#     109     session = await self.exit_stack.enter_async_context(
#     110         ClientSession(
#     111             read,
#    (...)    116         )
#     117     )
# --> 118     await session.initialize()
#     119     self.session = session
#     120 except Exception as e:
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/mcp/client/session.py:126, in ClientSession.initialize(self)
#     118 sampling = types.SamplingCapability()
#     119 roots = types.RootsCapability(
#     120     # TODO: Should this be based on whether we
#     121     # _will_ send notifications, or only whether
#     122     # they're supported?
#     123     listChanged=True,
#     124 )
# --> 126 result = await self.send_request(
#     127     types.ClientRequest(
#     128         types.InitializeRequest(
#     129             method="initialize",
#     130             params=types.InitializeRequestParams(
#     131                 protocolVersion=types.LATEST_PROTOCOL_VERSION,
#     132                 capabilities=types.ClientCapabilities(
#     133                     sampling=sampling,
#     134                     experimental=None,
#     135                     roots=roots,
#     136                 ),
#     137                 clientInfo=self._client_info,
#     138             ),
#     139         )
#     140     ),
#     141     types.InitializeResult,
#     142 )
#     144 if result.protocolVersion not in SUPPORTED_PROTOCOL_VERSIONS:
#     145     raise RuntimeError(
#     146         "Unsupported protocol version from the server: "
#     147         f"{result.protocolVersion}"
#     148     )
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/mcp/shared/session.py:256, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds)
#     254         response_or_error = await response_stream_reader.receive()
#     255 except TimeoutError:
# --> 256     raise McpError(
#     257         ErrorData(
#     258             code=httpx.codes.REQUEST_TIMEOUT,
#     259             message=(
#     260                 f"Timed out while waiting for response to "
#     261                 f"{request.__class__.__name__}. Waited "
#     262                 f"{timeout} seconds."
#     263             ),
#     264         )
#     265     )
#     267 if isinstance(response_or_error, JSONRPCError):
#     268     raise McpError(response_or_error.error)
#
# McpError: Timed out while waiting for response to ClientRequest. Waited 60.0 seconds.

# %%
question = "My name's Ed. What do you know about me?"

async with MCPServerStdio(params=params, client_session_timeout_seconds=60) as mcp_server:
    agent = Agent(name="agent", instructions=instructions, model=model, mcp_servers=[mcp_server])
    with trace("conversation"):
        result = await Runner.run(agent, question)
    display(Markdown(result.final_output))

# %% [markdown]
# ### Check the trace:
#
# https://platform.openai.com/traces

# %% [markdown]
# ## Second new MCP Server: Brave Search
#
#
#
# https://brave.com/search/api/
#
# Set up your account, and put your key in the .env under `BRAVE_API_KEY`

# %%
env = {"BRAVE_API_KEY": os.getenv("BRAVE_API_KEY")}
params = {"command": "npx", "args": ["-y", "@modelcontextprotocol/server-brave-search"], "env": env}

async with MCPServerStdio(params=params, client_session_timeout_seconds=60) as server:
    mcp_tools = await server.list_tools()

# %%
mcp_tools
# Out:
# [Tool(name='brave_web_search', description='Performs a web search using the Brave Search API, ideal for general queries, news, articles, and online content. Use this for broad information gathering, recent events, or when you need diverse web sources. Supports pagination, content filtering, and freshness controls. Maximum 20 results per request, with offset for pagination. ', inputSchema={'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'Search query (max 400 chars, 50 words)'}, 'count': {'type': 'number', 'description': 'Number of results (1-20, default 10)', 'default': 10}, 'offset': {'type': 'number', 'description': 'Pagination offset (max 9, default 0)', 'default': 0}}, 'required': ['query']}, annotations=None),
#  Tool(name='brave_local_search', description="Searches for local businesses and places using Brave's Local Search API. Best for queries related to physical locations, businesses, restaurants, services, etc. Returns detailed information including:\n- Business names and addresses\n- Ratings and review counts\n- Phone numbers and opening hours\nUse this when the query implies 'near me' or mentions specific locations. Automatically falls back to web search if no local results are found.", inputSchema={'type': 'object', 'properties': {'query': {'type': 'string', 'description': "Local search query (e.g. 'pizza near Central Park')"}, 'count': {'type': 'number', 'description': 'Number of results (1-20, default 5)', 'default': 5}}, 'required': ['query']}, annotations=None)]

# %%
instructions = "You are able to search the web for information and briefly summarize the takeaways."
request = f"Please research the latest news on Amazon stock price and briefly summarize its outlook. \
For context, the current date is {datetime.now().strftime('%Y-%m-%d')}"
model = "gpt-4o-mini"

# %%
async with MCPServerStdio(params=params, client_session_timeout_seconds=60) as mcp_server:
    agent = Agent(name="agent", instructions=instructions, model=model, mcp_servers=[mcp_server])
    with trace("conversation"):
        result = await Runner.run(agent, request)
    display(Markdown(result.final_output))
# Out:
# Here's a summary of the latest news regarding Amazon's stock outlook as of July 2025:
#
# 1. **Current Stock Price**: Amazon (NASDAQ: AMZN) is currently priced around $246.60, with a reported median one-year price target of $246.60, suggesting a potential upside of about 11% from current prices.
#
# 2. **Earnings Performance**: In Q1 2025, Amazon Ads reported revenues of $13.9 billion, representing a 19% year-over-year increase. This positive growth is a key indicator of the company's ongoing business health.
#
# 3. **Valuation Perspective**: Amazon's stock is trading at about 37 times its trailing twelve months earnings, which is seen as a premium. However, this valuation is much lower than its three-year average of 83, making it appear more attractive relative to historical averages.
#
# 4. **Analyst Ratings**: Truist Securities recently raised its price target for Amazon to $250 from $226, maintaining a "Buy" recommendation, underscoring positive sentiment among analysts.
#
# 5. **Market Movement**: The stock has shown a year-to-date gain of 1.42% and an increase of 12.07% over the past year, indicating steady performance amidst broader market fluctuations.
#
# Overall, analysts remain optimistic about Amazon's stock, with favorable price targets and revenue growth from its advertising segment suggesting potential for continued gains.

# %% [markdown]
# ## Third MCP Server: Polygon.io MCP Server

# %% [markdown]
# Introducing polygon.io
#
# Polygon.io is a hugely popular financial data provider. It has a free plan and a paid plan. And it also has an MCP Server!
#
# First, read up on polygon.io on their excellent website, including looking at their pricing:
#
# https://polygon.io
#
# 1. Please sign up for polygon.io (top right)
# 2. Once signed in, please select "Keys" in the left hand navigation
# 3. Press the blue "New Key" button
# 4. Copy the key name
# 5. Edit your .env file and add the row:
#
# `POLYGON_API_KEY=xxxx`
#
# This section covers the paid plan, but I've set up a free alternative too. Just use the `.env` file to control which one is used:
#
# If you do decide to have a paid plan, please add this to your .env file to indicate:
#
# `POLYGON_PLAN=paid`
#
# And if you decide to go all the way for the realtime API, then please do:
#
# `POLYGON_PLAN=realtime`

# %%
async with MCPServerStdio(
    params={
        "command": "npx",
        "args": ["-y", "@modelcontextprotocol/server-filesystem", "./sandbox"],
    }
) as server:
    mcp_tools = await server.list_tools()

# %%
polygon_api_key = os.getenv("POLYGON_API_KEY")

params = {"command": "uvx",
          "args": ["--from", "git+https://github.com/polygon-io/mcp_polygon@master", "mcp_polygon"],
          "env": {"POLYGON_API_KEY": polygon_api_key}
          }
async with MCPServerStdio(params=params, client_session_timeout_seconds=60) as server:
    mcp_tools = await server.list_tools()
mcp_tools
# Out:
# Error initializing MCP server: Timed out while waiting for response to ClientRequest. Waited 60.0 seconds.
# Error cleaning up server: unhandled errors in a TaskGroup (1 sub-exception)
# ---------------------------------------------------------------------------
# WouldBlock                                Traceback (most recent call last)
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/streams/memory.py:111, in MemoryObjectReceiveStream.receive(self)
#     110 try:
# --> 111     return self.receive_nowait()
#     112 except WouldBlock:
#     113     # Add ourselves in the queue
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/streams/memory.py:106, in MemoryObjectReceiveStream.receive_nowait(self)
#     104     raise EndOfStream
# --> 106 raise WouldBlock
#
# WouldBlock:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/_core/_tasks.py:115, in fail_after(delay, shield)
#     112 with get_async_backend().create_cancel_scope(
#     113     deadline=deadline, shield=shield
#     114 ) as cancel_scope:
# --> 115     yield cancel_scope
#     117 if cancel_scope.cancelled_caught and current_time() >= cancel_scope.deadline:
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/mcp/shared/session.py:254, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds)
#     253     with anyio.fail_after(timeout):
# --> 254         response_or_error = await response_stream_reader.receive()
#     255 except TimeoutError:
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/streams/memory.py:119, in MemoryObjectReceiveStream.receive(self)
#     118 try:
# --> 119     await receive_event.wait()
#     120 finally:
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:1774, in Event.wait(self)
#    1773 else:
# -> 1774     await self._event.wait()
#
# File ~/.python/current/lib/python3.12/asyncio/locks.py:212, in Event.wait(self)
#     211 try:
# --> 212     await fut
#     213     return True
#
# CancelledError: Cancelled by cancel scope 72e2056050d0
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File /workspaces/action/.venv/lib/python3.12/site-packages/mcp/shared/session.py:253, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds)
#     252 try:
# --> 253     with anyio.fail_after(timeout):
#     254         response_or_error = await response_stream_reader.receive()
#
# File ~/.python/current/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/anyio/_core/_tasks.py:118, in fail_after(delay, shield)
#     117 if cancel_scope.cancelled_caught and current_time() >= cancel_scope.deadline:
# --> 118     raise TimeoutError
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# McpError                                  Traceback (most recent call last)
# Cell In[14], line 7
#       1 polygon_api_key = os.getenv("POLYGON_API_KEY")
#       3 params = {"command": "uvx",
#       4           "args": ["--from", "git+https://github.com/polygon-io/mcp_polygon@master", "mcp_polygon"],
#       5           "env": {"POLYGON_API_KEY": polygon_api_key}
#       6           }
# ----> 7 async with MCPServerStdio(params=params, client_session_timeout_seconds=60) as server:
#       8     mcp_tools = await server.list_tools()
#       9 mcp_tools
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/agents/mcp/server.py:94, in _MCPServerWithClientSession.__aenter__(self)
#      93 async def __aenter__(self):
# ---> 94     await self.connect()
#      95     return self
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/agents/mcp/server.py:118, in _MCPServerWithClientSession.connect(self)
#     108     read, write = transport
#     109     session = await self.exit_stack.enter_async_context(
#     110         ClientSession(
#     111             read,
#    (...)    116         )
#     117     )
# --> 118     await session.initialize()
#     119     self.session = session
#     120 except Exception as e:
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/mcp/client/session.py:126, in ClientSession.initialize(self)
#     118 sampling = types.SamplingCapability()
#     119 roots = types.RootsCapability(
#     120     # TODO: Should this be based on whether we
#     121     # _will_ send notifications, or only whether
#     122     # they're supported?
#     123     listChanged=True,
#     124 )
# --> 126 result = await self.send_request(
#     127     types.ClientRequest(
#     128         types.InitializeRequest(
#     129             method="initialize",
#     130             params=types.InitializeRequestParams(
#     131                 protocolVersion=types.LATEST_PROTOCOL_VERSION,
#     132                 capabilities=types.ClientCapabilities(
#     133                     sampling=sampling,
#     134                     experimental=None,
#     135                     roots=roots,
#     136                 ),
#     137                 clientInfo=self._client_info,
#     138             ),
#     139         )
#     140     ),
#     141     types.InitializeResult,
#     142 )
#     144 if result.protocolVersion not in SUPPORTED_PROTOCOL_VERSIONS:
#     145     raise RuntimeError(
#     146         "Unsupported protocol version from the server: "
#     147         f"{result.protocolVersion}"
#     148     )
#
# File /workspaces/action/.venv/lib/python3.12/site-packages/mcp/shared/session.py:256, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds)
#     254         response_or_error = await response_stream_reader.receive()
#     255 except TimeoutError:
# --> 256     raise McpError(
#     257         ErrorData(
#     258             code=httpx.codes.REQUEST_TIMEOUT,
#     259             message=(
#     260                 f"Timed out while waiting for response to "
#     261                 f"{request.__class__.__name__}. Waited "
#     262                 f"{timeout} seconds."
#     263             ),
#     264         )
#     265     )
#     267 if isinstance(response_or_error, JSONRPCError):
#     268     raise McpError(response_or_error.error)
#
# McpError: Timed out while waiting for response to ClientRequest. Waited 60.0 seconds.

# %% [markdown]
# ### Wow that's a lot of tools!
#
# Let's try them out - hopefully the sheer number of tools doesn't overwhelm gpt-4o-mini!
#
# With the $29 monthly plan, we don't have access to some of the APIs, so I've needed to specify which APIs can be called.
#
# If you've splashed out on a bigger plan, feel free to remove my extra constraint..

# %%
instructions = "You answer questions about the stock market."
request = "What's the share price of Apple? Use your get_snapshot_ticker tool to get the latest price."
model = "gpt-4o-mini"

async with MCPServerStdio(params=params, client_session_timeout_seconds=60) as mcp_server:
    agent = Agent(name="agent", instructions=instructions, model=model, mcp_servers=[mcp_server])
    with trace("conversation"):
        result = await Runner.run(agent, request)
    display(Markdown(result.final_output))

# %% [markdown]
# ## In total, how many MCP servers and tools have we looked at?

# %%
from mcp_params import trader_mcp_server_params, researcher_mcp_server_params

all_params = trader_mcp_server_params + researcher_mcp_server_params("ed")

count = 0
for each_params in all_params:
    async with MCPServerStdio(params=each_params, client_session_timeout_seconds=60) as server:
        mcp_tools = await server.list_tools()
        count += len(mcp_tools)
print(f"We have {len(all_params)} MCP servers, and {count} tools")

# %% [markdown]
# ## OK - Let's build an application that uses all of these tools!!
